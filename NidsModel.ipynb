# %% [markdown]
# # NIDS model

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd

df_train = pd.read_csv('Datasets/UNSW_NB15_testing-set.csv')
df_train.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes       rate
# 0   1  0.121478   tcp       -   FIN      6      4     258     172  74.087490  \
# 1   2  0.649902   tcp       -   FIN     14     38     734   42014  78.473372
# 2   3  1.623129   tcp       -   FIN      8     16     364   13186  14.170161
# 3   4  1.681642   tcp     ftp   FIN     12     12     628     770  13.677108
# 4   5  0.449454   tcp       -   FIN     10      6     534     268  33.373826
#
#    ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd
# 0  ...                 1               1             0           0  \
# 1  ...                 1               2             0           0
# 2  ...                 1               3             0           0
# 3  ...                 1               3             1           1
# 4  ...                 1              40             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  attack_cat
# ...

# %%
df_test = pd.read_csv('Datasets/UNSW_NB15_training-set.csv')
df_test.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes
# 0   1  0.000011   udp       -   INT      2      0     496       0  \
# 1   2  0.000008   udp       -   INT      2      0    1762       0
# 2   3  0.000005   udp       -   INT      2      0    1068       0
# 3   4  0.000006   udp       -   INT      2      0     900       0
# 4   5  0.000010   udp       -   INT      2      0    2126       0
#
#           rate  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login
# 0   90909.0902  ...                 1               2             0  \
# 1  125000.0003  ...                 1               2             0
# 2  200000.0051  ...                 1               3             0
# 3  166666.6608  ...                 1               3             0
# 4  100000.0025  ...                 1               3             0
#
#    ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports
# 0           0                 0           1           2                0  \
# ...

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Removing unnecessary variables

# %%
df_train = df_train.drop(['attack_cat', 'proto', 'service', 'state', 'id', 'spkts', 'dpkts', 'sloss', 'dloss', 'ct_dst_src_ltm'], axis = 1)
df_train.head()
# Out:
#         dur  sbytes  dbytes       rate  sttl  dttl         sload
# 0  0.121478     258     172  74.087490   252   254  14158.942380  \
# 1  0.649902     734   42014  78.473372    62   252   8395.112305
# 2  1.623129     364   13186  14.170161    62   252   1572.271851
# 3  1.681642     628     770  13.677108    62   252   2740.178955
# 4  0.449454     534     268  33.373826   254   252   8561.499023
#
#            dload      sinpkt      dinpkt  ...  ct_dst_ltm  ct_src_dport_ltm
# 0    8495.365234   24.295600    8.375000  ...           1                 1  \
# 1  503571.312500   49.915000   15.432865  ...           1                 1
# 2   60929.230470  231.875571  102.737203  ...           2                 1
# 3    3358.622070  152.876547   90.235726  ...           2                 1
# 4    3987.059814   47.750333   75.659602  ...           2                 2
#
#    ct_dst_sport_ltm  is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm
# ...

# %%
df_test = df_test.drop(['attack_cat', 'proto', 'service', 'state', 'id', 'spkts', 'dpkts', 'sloss', 'dloss', 'ct_dst_src_ltm'], axis = 1)
df_test.head()
# Out:
#         dur  sbytes  dbytes         rate  sttl  dttl        sload  dload
# 0  0.000011     496       0   90909.0902   254     0  180363632.0    0.0  \
# 1  0.000008    1762       0  125000.0003   254     0  881000000.0    0.0
# 2  0.000005    1068       0  200000.0051   254     0  854400000.0    0.0
# 3  0.000006     900       0  166666.6608   254     0  600000000.0    0.0
# 4  0.000010    2126       0  100000.0025   254     0  850400000.0    0.0
#
#    sinpkt  dinpkt  ...  ct_dst_ltm  ct_src_dport_ltm  ct_dst_sport_ltm
# 0   0.011     0.0  ...           1                 1                 1  \
# 1   0.008     0.0  ...           1                 1                 1
# 2   0.005     0.0  ...           1                 1                 1
# 3   0.006     0.0  ...           2                 2                 1
# 4   0.010     0.0  ...           2                 2                 1
#
#    is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst
# ...

# %% [markdown]
# ### Data seperation as X and Y

# %%
y_train = df_train['label']
y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
y_test = df_test['label']
y_test.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
x_train = df_train.drop(['label'], axis=1)
x_train.head()
# Out:
#         dur  sbytes  dbytes       rate  sttl  dttl         sload
# 0  0.121478     258     172  74.087490   252   254  14158.942380  \
# 1  0.649902     734   42014  78.473372    62   252   8395.112305
# 2  1.623129     364   13186  14.170161    62   252   1572.271851
# 3  1.681642     628     770  13.677108    62   252   2740.178955
# 4  0.449454     534     268  33.373826   254   252   8561.499023
#
#            dload      sinpkt      dinpkt  ...  ct_state_ttl  ct_dst_ltm
# 0    8495.365234   24.295600    8.375000  ...             0           1  \
# 1  503571.312500   49.915000   15.432865  ...             1           1
# 2   60929.230470  231.875571  102.737203  ...             1           2
# 3    3358.622070  152.876547   90.235726  ...             1           2
# 4    3987.059814   47.750333   75.659602  ...             1           2
#
#    ct_src_dport_ltm  ct_dst_sport_ltm  is_ftp_login  ct_ftp_cmd
# 0                 1                 1             0           0  \
# ...

# %%
x_test = df_test.drop(['label'], axis=1)
x_test.head()
# Out:
#         dur  sbytes  dbytes         rate  sttl  dttl        sload  dload
# 0  0.000011     496       0   90909.0902   254     0  180363632.0    0.0  \
# 1  0.000008    1762       0  125000.0003   254     0  881000000.0    0.0
# 2  0.000005    1068       0  200000.0051   254     0  854400000.0    0.0
# 3  0.000006     900       0  166666.6608   254     0  600000000.0    0.0
# 4  0.000010    2126       0  100000.0025   254     0  850400000.0    0.0
#
#    sinpkt  dinpkt  ...  ct_state_ttl  ct_dst_ltm  ct_src_dport_ltm
# 0   0.011     0.0  ...             2           1                 1  \
# 1   0.008     0.0  ...             2           1                 1
# 2   0.005     0.0  ...             2           1                 1
# 3   0.006     0.0  ...             2           2                 2
# 4   0.010     0.0  ...             2           2                 2
#
#    ct_dst_sport_ltm  is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm
# ...

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### XGBoost classification

# %%
import sklearn
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# ### Applying model to make prediction

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
y_train_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y_test_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_test_pred)
accuracy*100
# Out:
# 86.65889326142934

# %% [markdown]
# ### Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

params={'max_depth':[5], 'n_estimators': [200,300,400],
            'learning_rate': [0.15,0.20], 'subsample':[0.3,0.5,0.7]}

model_2 = GridSearchCV(XGBClassifier(),params,refit=True,verbose=3)
model_2.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.3;, score=0.933 total time=  17.6s
# [CV 2/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.3;, score=0.955 total time=  24.1s
# [CV 3/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.3;, score=0.976 total time=  22.3s
# [CV 4/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.3;, score=0.915 total time=  20.7s
# [CV 5/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.3;, score=0.788 total time=  21.4s
# [CV 1/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.5;, score=0.932 total time=  24.7s
# [CV 2/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.5;, score=0.957 total time=  25.3s
# [CV 3/5] END learning_rate=0.15, max_depth=5, n_estimators=200, subsample=0.5;, score=0.977 total time=  25.8s
# ...

# %%
model_2.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 400, 'subsample': 0.3}

# %%
model_2.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=400, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
pred_2 = model_2.predict(x_test)

# %%
score_2 = model_2.score(x_test,y_test)
print("Accuracy of 1st test model: ",score_2*100)
# Out:
# Accuracy of 1st test model:  86.24957489190108

# %% [markdown]
# #### model 3

# %%
params_3 = {'max_depth':[5], 'n_estimators': [200,300,500],
            'learning_rate': [0.20,0.30], 'subsample':[0.5,0.6,0.7]}
model_3 = GridSearchCV(XGBClassifier(),params_3,refit=True,verbose=3,
                       cv=5,n_jobs=-1)
model_3.fit(x_train, y_train)

# %% [markdown]
# ## Saving the model using Joblib

# %%
import joblib

joblib.dump(model,'nids_Model')
# Out:
# ['nids_Model']
